# %% [markdown]
# # Indeed Job Scraper - Trial Run with job description
# create a general purpose job scraper

# %%
import re
import csv
from datetime import datetime
import requests
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %% [markdown]
# ### Setup the query and url

# %%
def get_url(position, location):
    """Generate url from position and location"""
    template = 'https://www.indeed.com/jobs?q={}&l={}'
    position = position.replace(' ', '+')
    location = location.replace(' ', '+')
    url = template.format(position, location)
    return url

# %%
url = get_url('organizational development', 'charlotte nc')
print(url)
# Out:
# https://www.indeed.com/jobs?q=organizational+development&l=charlotte+nc

# %% [markdown]
# ### Extract the html data

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
#cards = soup.find_all('div', 'mosaic-provider-jobcards')

cards = soup.find_all('a', class_="tapItem")

# %%
print(cards)
# Out:
# [<a class="tapItem fs-unmask result job_4b19cf5f7341eadb sponsoredJob resultWithShelf sponTapItem desktop" data-ci="385959398" data-empn="6616844022494418" data-hide-spinner="true" data-hiring-event="false" data-jk="4b19cf5f7341eadb" data-mobtk="1g0781rn3q07f800" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0CCrxbiXcrrcnkti5OAxjJFmqdicGijc3TcbLF315CLw53pnmhbQC08b2FtdQe2zf02X0KX2zoRaBYwG7gYm9EwwaK0gWtwNuEgnvh8_0nfV9v8ckU34jn9_LcG6_6kqmpAvmNmvbg3Ugn3Oh3V5VQUsmSH894bksYhWKmOtZMUCnY6mi4T8cR7iSSFh0sdmySlT-lu4IuugDKHd1Bw9oSxmntuj6Iw0NKmM3yqTa2tzTL5VfQYMN0ENNpDZRxWnAx0l402mRWls2w38G0Dwfz_kHNltJW_WNLZQ3eXrAqLZ15Q0eP2dBCr2Bl9jOHURUcYLtBxvxZzoUYFrteIv0iS2-BMXpRWv0Q0CPx67HKQ-hawLGRm4FSq9-Ax5p0PyJDNGxEAxDlxQOApoAcdSK59SyxpEJZ_fpizKGkqT1uMeYzs3PZo2ZU2-eBZnpP8SB2rbypCUccNMexanR-3UgGUbpuymKMMsgPlcjvXgyqXhi1H6ZDeHbN_H_BlENcJIKrKM8eNZmtW-VRizyTAjcxd&amp;p=0&amp;fvj=1&amp;vjs=3" id="sj_4b19cf5f7341eadb" rel="nofollow" target="_blank"><style data-emotion="css 11g4k3a">.css-11g4k3a{box-sizing:border-box;margin:0;min-width:0;box-shadow:0 0.125rem 0.25rem rgba(45, 45, 45, 0.12),0 0.0625rem 0.1875rem rgba(45, 45, 45, 0.16),0 0 0.125rem rgba(45, 45, 45, 0.2);border:none;margin:1px 1rem 0.75rem;border-radius:8px;}</style><div class="slider_container css-11g4k3a eu4oa1w0"><div class="slider_list"><div class="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="heading4 color-text-primary singleLineTitle tapItem-gutter"><h2 class="jobTitle jobTitle-color-purple"><span title="Summer Tutoring Program Coordinator, In-Person">Summer Tutoring Program Coordinator, In-Person</span></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName"><a class="turnstileLink companyOverviewLink" data-tn-element="companyName" href="/cmp/University-Instructors,-Inc.-1" rel="noopener" target="_blank">University Instructors, LLC</a></span><span class="ratingsDisplay withRatingLink"><a aria-label="Company rating 3.8 out of 5 stars" class="ratingLink" data-tn-variant="cmplinktst2" href="/cmp/University-Instructors,-Inc.-1/reviews" rel="noopener" target="_blank" title="University Instructors, LLC reviews"><span aria-label="3.8 of stars rating" class="ratingNumber" role="img"><span aria-hidden="true">3.8</span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.21932 15.7563 3.54584 15.5593L8 12.8709Z" fill="#767676"></path></svg></span></a></span><div class="companyLocation">Charlotte, NC 28202<!-- --> <span class="companyLocation--extras">(<!-- -->Downtown Charlotte area<!-- -->)</span></div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><div class="attribute_snippet"><svg aria-hidden="true" aria-label="Salary" fill="none" role="presentation" viewbox="0 0 16 13" xmlns="http://www.w3.org/2000/svg"><defs></defs><path clip-rule="evenodd" d="M2.45168 6.10292c-.30177-.125-.62509-.18964-.95168-.1903V4.08678c.32693-.00053.6506-.06518.95267-.1903.30331-.12564.57891-.30979.81105-.54193.23215-.23215.4163-.50775.54194-.81106.12524-.30237.18989-.62638.19029-.95365H9.0902c0 .3283.06466.65339.1903.9567.12564.30331.30978.57891.54193.81106.23217.23215.50777.41629.81107.54193.3032.12558.6281.19024.9562.1903v1.83556c-.3242.00155-.6451.06616-.9448.19028-.3033.12563-.5789.30978-.81102.54193-.23215.23214-.4163.50774-.54193.81106-.12332.2977-.18789.61638-.19024.93849H3.99 ...
# <li style="margin-bottom:0px;">Good time management and <b>organizational</b> skills, including prioritizing, scheduling, and adapting as necessary.</li>
# <li>Observe tutors during small group instruction.</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active
span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15. ...
# <li style="margin-bottom:0px;">Experience writing and editing <b>organizational</b> communications.</li>
# <li>Assist staff with pre-proposal strategy <b>development</b> and grant writing support.</li>
# ...
# <li>Operate with a wide perspective across needs and teams (e.g., Global use of US solutions, joint <b>development</b> of shared needs).</li>
# </ul></div><span class="date"><span class="visually-hidden">Posted</span>9 days ago</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">More...</button></div><div class="tab-container"><div class="more-links-container result-tab" role="presentation"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">View all <a href="/q-Deloitte-l-Charlotte,-NC-jobs.html">Deloitte jobs in Charlotte, NC</a> - <a href="/l-Charlotte,-NC-jobs.html">Charlotte jobs</a></span></li><li><span class="mat">Salary Search: <a href="/career/development-manager/salaries/Charlotte--NC?campaignid=serp-more&amp;fromjk=77a2fe945b728b8d&amp;from=serp-more">Development Manager, Deloitte Leadership Academy - Learning and Development salaries in Charlotte, NC</a></span></li><li><span class="mat">See popular <a href="/cmp/Deloitte/faq">questions &amp; answers about Deloitte</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item"></div></div></div><div class="kebabMenu"><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions" class="kebabMenu-button"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></a>, <a class="tapItem fs-unmask result job_8253121c7811654e resultWithShelf sponTapItem desktop" data-hide-spinner="true" data-hiring-event="false" data-jk="8253121c7811654e" data-mobtk="1g0781rn3q07f800" href="/rc/clk?jk=8253121c7811654e&amp;fccid=8e5415c099aa948c&amp;vjs=3" id="job_8253121c7811654e" rel="nofollow" target="_blank"><style data-emotion="css 11g4k3a">.css-11g4k3a{box-sizing:border-box;margin:0;min-width:0;box-shadow:0 0.125rem 0.25rem rgba(45, 45, 45, 0.12),0 0.0625rem 0.1875rem rgba(45, 45, 45, 0.16),0 0 0.125rem rgba(45, 45, 45, 0.2);border:none;margin:1px 1rem 0.75rem;border-radius:8px;}</style><div class="slider_container css-11g4k3a eu4oa1w0"><div class="slider_list"><div class="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="heading4 color-text-primary singleLineTitle tapItem-gutter"><h2 class="jobTitle jobTitle-color-purple jobTitle-newJob"><div class="new topLeft holisticNewBlue desktop"><span class="label">new</span></div><span title="Training Specialist, Human Resources">Training Specialist, Human Resources</span></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName"><a class="turnstileLink companyOverviewLink" data-tn-element="companyName" href="/cmp/Publix" rel="noopener" target="_blank">Publix</a></span><span class="ratingsDisplay withRatingLink"><a aria-label="Company rating 4 out of 5 stars" class="ratingLink" data-tn-variant="cmplinktst2" href="/cmp/Publix/reviews" rel="noopener" target="_blank" title="Publix reviews"><span aria-label="4.0 of stars rating" class="ratingNumber" role="img"><span aria-hidden="true">4.0</span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149 ...
# <li style="margin-bottom:0px;">The Training Specialist reports to the Manager of Training Delivery.</li>
# <li>Present core curriculum and change management course material to Publix managers of all…</li>
# </ul></div><span class="date"><span class="visually-hidden">Posted</span>Today</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">More...</button></div><div class="tab-container"><div class="more-links-container result-tab" role="presentation"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">View all <a href="/q-Publix-l-Charlotte,-NC-jobs.html">Publix jobs in Charlotte, NC</a> - <a href="/l-Charlotte,-NC-jobs.html">Charlotte jobs</a></span></li><li><span class="mat">Salary Search: <a href="/career/training-specialist/salaries/Charlotte--NC?campaignid=serp-more&amp;fromjk=8253121c7811654e&amp;from=serp-more">Training Specialist, Human Resources salaries in Charlotte, NC</a></span></li><li><span class="mat">See popular <a href="/cmp/Publix/faq">questions &amp; answers about Publix</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item"></div></div></div><div class="kebabMenu"><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions" class="kebabMenu-button"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></a>, <a class="tapItem fs-unmask result job_2bd3e0446c8dbe43 resultWithShelf sponTapItem desktop" data-hide-spinner="true" data-hiring-event="false" data-jk="2bd3e0446c8dbe43" data-mobtk="1g0781rn3q07f800" href="/company/Mecklenburg-County/jobs/Management-Analyst-2bd3e0446c8dbe43?fccid=88a0faf78b0e5032&amp;vjs=3" id="job_2bd3e0446c8dbe43" rel="nofollow" target="_blank"><style data-emotion="css 11g4k3a">.css-11g4k3a{box-sizing:border-box;margin:0;min-width:0;box-shadow:0 0.125rem 0.25rem rgba(45, 45, 45, 0.12),0 0.0625rem 0.1875rem rgba(45, 45, 45, 0.16),0 0 0.125rem rgba(45, 45, 45, 0.2);border:none;margin:1px 1rem 0.75rem;border-radius:8px;}</style><div class="slider_container css-11g4k3a eu4oa1w0"><div class="slider_list"><div class="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="heading4 color-text-primary singleLineTitle tapItem-gutter"><h2 class="jobTitle jobTitle-color-purple"><span title="Management Analyst - Public Health">Management Analyst - Public Health</span></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName"><a class="turnstileLink companyOverviewLink" data-tn-element="companyName" href="/cmp/Mecklenburg-County" rel="noopener" target="_blank">County of Mecklenburg</a></span><span class="ratingsDisplay withRatingLink"><a aria-label="Company rating 3.7 out of 5 stars" class="ratingLink" data-tn-variant="cmplinktst2" href="/cmp/Mecklenburg-County/reviews" rel="noopener" target="_blank" title="County of Mecklenburg reviews"><span aria-label="3.7 of stars rating" class="ratingNumber" role="img"><span aria-hidden="true">3.7</span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.219 ...
# <li style="margin-bottom:0px;">Recommend new systems, procedures, or <b>organizational</b> changes.</li>
# <li>Technical / Professional Knowledge &amp; Skills: Having achieved a satisfactory level of technical and…</li>
# </ul></div><span class="date"><span class="visually-hidden">Posted</span>28 days ago</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">More...</button></div><div class="tab-container"><div class="more-links-container result-tab" role="presentation"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">View all <a href="/q-County-of-Mecklenburg-l-Charlotte,-NC-jobs.html">County of Mecklenburg jobs in Charlotte, NC</a> - <a href="/l-Charlotte,-NC-jobs.html">Charlotte jobs</a></span></li><li><span class="mat">Salary Search: <a href="/career/management-analyst/salaries/28202--NC?campaignid=serp-more&amp;fromjk=2bd3e0446c8dbe43&amp;from=serp-more">Management Analyst - Public Health salaries in Charlotte, NC</a></span></li><li><span class="mat">See popular <a href="/cmp/Mecklenburg-County/faq">questions &amp; answers about County of Mecklenburg</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item"></div></div></div><div class="kebabMenu"><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions" class="kebabMenu-button"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></a>, <a class="tapItem fs-unmask result job_06349d17267c1b99 resultWithShelf sponTapItem desktop" data-hide-spinner="true" data-hiring-event="false" data-jk="06349d17267c1b99" data-mobtk="1g0781rn3q07f800" href="/rc/clk?jk=06349d17267c1b99&amp;fccid=2973259ddc967948&amp;vjs=3" id="job_06349d17267c1b99" rel="nofollow" target="_blank"><style data-emotion="css 11g4k3a">.css-11g4k3a{box-sizing:border-box;margin:0;min-width:0;box-shadow:0 0.125rem 0.25rem rgba(45, 45, 45, 0.12),0 0.0625rem 0.1875rem rgba(45, 45, 45, 0.16),0 0 0.125rem rgba(45, 45, 45, 0.2);border:none;margin:1px 1rem 0.75rem;border-radius:8px;}</style><div class="slider_container css-11g4k3a eu4oa1w0"><div class="slider_list"><div class="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="heading4 color-text-primary singleLineTitle tapItem-gutter"><h2 class="jobTitle jobTitle-color-purple"><span title="HR Sr Representative">HR Sr Representative</span></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName"><a class="turnstileLink companyOverviewLink" data-tn-element="companyName" href="/cmp/PepsiCo" rel="noopener" target="_blank">PepsiCo</a></span><span class="ratingsDisplay withRatingLink"><a aria-label="Company rating 3.8 out of 5 stars" class="ratingLink" data-tn-variant="cmplinktst2" href="/cmp/PepsiCo/reviews" rel="noopener" target="_blank" title="PepsiCo reviews"><span aria-label="3.8 of stars rating" class="ratingNumber" role="img"><span aria-hidden="true">3.8</span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.21932 15.7563 3.54584 15.5593L8 12.8709Z" fill="#767676"></pat ...
# <li>Understanding of, and some experience with, most or all of the core aspects of Human Resource Management (staffing; employee relations; labor relations;…</li>
# </ul></div><span class="date"><span class="visually-hidden">Posted</span>30+ days ago</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">More...</button></div><div class="tab-container"><div class="more-links-container result-tab" role="presentation"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">View all <a href="/q-PepsiCo-l-Charlotte,-NC-jobs.html">PepsiCo jobs in Charlotte, NC</a> - <a href="/l-Charlotte,-NC-jobs.html">Charlotte jobs</a></span></li><li><span class="mat">Salary Search: <a href="/career/human-resources-representative/salaries/Charlotte--NC?campaignid=serp-more&amp;fromjk=06349d17267c1b99&amp;from=serp-more">HR Sr Representative salaries in Charlotte, NC</a></span></li><li><span class="mat">See popular <a href="/cmp/PepsiCo/faq">questions &amp; answers about PepsiCo</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item"></div></div></div><div class="kebabMenu"><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions" class="kebabMenu-button"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></a>]

# %% [markdown]
# ### Prototype the model with a single record

# %%
card = cards[0]

# %%
job_title = card.find('h2').get_text()

# %%
company = card.find('span', class_='companyName').get_text()

# %%
job_location = card.find('div', class_='companyLocation').get_text()

# %%
post_date = card.find('span', 'date').text
today = datetime.today().strftime('%Y-%m-%d')

# %%
summary = card.find('div', class_='job-snippet').get_text().strip()

# %%
# this does not exists for all jobs, so handle the exceptions
salary_tag = card.find('span', 'salaryText')
if salary_tag:
    salary = salary_tag.text.strip()
else:
    salary = ''

# %%
job_url = 'https://www.indeed.com' + card['href']

# %% [markdown]
# #### Getting Job description

# %%
# regex pattern to identify job keys
jk_pattern = re.compile(r"jk:\'([a-zA-Z0-9]+)'")

# %%
# request parameters
params = { "q": "oranizational+development", "l": "charlotte+nc", "start": 0 }
url = "https://www.indeed.com/jobs"
job_keys = set()

# %%
# get the first 10 pages as a test
for x in range(10):
    response = requests.get(url, params=params)
    if not response.status_code == 200:
        break
    else:
        keys = jk_pattern.findall(response.text)
        if len(keys) > 0:
            for key in keys:
                job_keys.add(key)
    
    params['start'] += 20
    sleep(randint(0, 3))

# %%
len(job_keys)
# Out:
# 150

# %%
# job url template
template = "https://www.indeed.com/viewjob?jk={}"

# %%
# raw html from job page.... scraping log to be applied with BeautifulSoup here...
jk = job_keys.pop()
jd_url = template.format(jk)
jd_response = requests.get(job_url)

# %%
jd_soup = BeautifulSoup(jd_response.text, 'html.parser')

# %%
job_description = jd_soup.find("div", id="jobDescriptionText").text

# %%
record = (job_title, company, job_location, post_date, today, summary, salary, job_url,job_description)

# %%
record
# Out:
# ('Summer Tutoring Program Coordinator, In-Person',
#  'University Instructors, LLC',
#  'Charlotte, NC 28202 (Downtown Charlotte area)',
#  'EmployerActive 1 day ago',
#  '2022-04-09',
#  'Good time management and organizational skills, including prioritizing, scheduling, and adapting as necessary.\nObserve tutors during small group instruction.',
#  '',
#  'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CCrxbiXcrrcnkti5OAxjJFmqdicGijc3TcbLF315CLw53pnmhbQC08b2FtdQe2zf02X0KX2zoRaBYwG7gYm9EwwaK0gWtwNuEgnvh8_0nfV9v8ckU34jn9_LcG6_6kqmpAvmNmvbg3Ugn3Oh3V5VQUsmSH894bksYhWKmOtZMUCnY6mi4T8cR7iSSFh0sdmySlT-lu4IuugDKHd1Bw9oSxmntuj6Iw0NKmM3yqTa2tzTL5VfQYMN0ENNpDZRxWnAx0l402mRWls2w38G0Dwfz_kHNltJW_WNLZQ3eXrAqLZ15Q0eP2dBCr2Bl9jOHURUcYLtBxvxZzoUYFrteIv0iS2-BMXpRWv0Q0CPx67HKQ-hawLGRm4FSq9-Ax5p0PyJDNGxEAxDlxQOApoAcdSK59SyxpEJZ_fpizKGkqT1uMeYzs3PZo2ZU2-eBZnpP8SB2rbypCUccNMexanR-3UgGUbpuymKMMsgPlcjvXgyqXhi1H6ZDeHbN_H_BlENcJIKrKM8eNZmtW-VRizyTAjcxd&p=0&fvj=1&vjs=3',
#  "\nUniversity Instructors (UI) is seeking a dynamic Program Coordinator with a passion for supporting students to lead our K-12 tutoring programs. In this role, you’ll work in schools to directly help students overcome learning losses experienced as a result of the pandemic.\nUniversity Instructors partners with schools to provide students with purposeful learning experiences led by inspirational educators. If you are committed to co-creating and implementing impactful instructional services for school partners to enhance student achievement and build local talent pipelines, apply now.\nRoles and Responsibilities\nIn this role, you’ll:\n\nSupport a caseload of K-12 schools and serve as a liaison between the UI team, UI tutors, school-level staff, and district staff.\nAct as a mentor for UI tutors by providing direction, support, and encouragement in all aspects of student services.\nMonitor all elements of school program implementation, including but not limited to tutor attendance, performance, material distribution, and student achievement through progress monitoring.\nLead and facilitate instructor orientation and trainings as needed.\nManage Site Coordinators and Lead Instructors if applicable.\nObserve tutors during small group instruction. Provide tutors with performance coaching to ensure effective classroom management and growth in student achievement.\nComplete required documentation for school visits.\nCommunicate and meet regularly with your supervisor to update them on progress, potential problems, and program concerns.\nInform your supervisor about changes at schools you support. This might look like program observations related to school administration and staff concerns, tutor performance and attendance, changes to a program’s setup, or effectiveness of the program.\nProvide tutors with effective solutions to behavioral or educational problems arising during student instruction following UI best practices.\nOversee completion, collection, and distribution of mid-program and end-of-program reports and surveys.\nReview and approve tutors’ timecards submissions for payment.\nLead the collaboration among UI teams (Business Development, Recruiting, Curriculum, Logistics, and Accounting) and clients (district partners and leaders at schools you support).\nConfirm and assign tutors to school locations account for partnership with clients and their needs.\nPartner with UI Recruiting Specialists to place newly recommended tutors.\nKeep open lines of communication with newly recommended tutors throughout their orientation and training to ensure all program details have been confirmed.\nMaintain a positive rapport with school administration and staff.\nAttend client meetings when appropriate.\nComplete other duties as assigned.\n\nKnowledge and Skills\nWe are looking for someone who can demonstrate:\n\nEffective oral and written communication skills\nAn understanding of instructional pedagogies and methodologies\nExcellent interpersonal skills\nStrong computer skills\nGood time management and organizational skills, including prioritizing, scheduling, and adapting as necessary\nThe ability to meet deadlines\nStrong ability to work both independently with little supervision and collaboratively as part of a writing team\n\nEducation and Work Experience\nAs a successful applicant, you must have a passion for advocating for and helping students succeed. Additionally, you will need to:\n\nHold a bachelor’s degree AND\nCommit to working 35-40 hours each week AND\nDemonstrate ONE of the following: 1) At least 2-3 years of experience working in a K-12 educational setting OR 2) Any similar combination of education and experience\n\nPrior supervisory and project management experience is preferred.\nJob Type: Full-time\nPay: $25.00 - $35.00 per hour\nSchedule:\n\nMonday to Friday\n\nEducation:\n\nBachelor's (Required)\n\nExperience:\n\nK-12: 2 years (Preferred)\n\nWork Location: One location\n")

# %% [markdown]
# ### Generalize the model with a function

# %%
def get_record(card):
    """Extract job data from a single record"""
    
    job_title = card.find('h2').get_text()
    company = card.find('span', class_='companyName').get_text()
    job_location = card.find('div', class_='companyLocation').get_text()
    post_date = card.find('span', 'date').text
    today = datetime.today().strftime('%Y-%m-%d')
    summary = card.find('div', class_='job-snippet').get_text().strip()
    job_url = 'https://www.indeed.com' + card['href']
    job_description = jd_soup.find("div", id="jobDescriptionText").text

    # this does not exists for all jobs, so handle the exceptions
    salary_tag = card.find('span', 'salaryText')
    if salary_tag:
        salary = salary_tag.text.strip()
    else:
        salary = ''  
        
    record = (job_title, company, job_location, post_date, today, summary, salary, job_url, job_description)
    return record

# %%
records = []

for card in cards:
    record = get_record(card)
    records.append(record)

# %% [markdown]
# ### Get the next page

# %%
while True:
    try:
        url = 'https://www.indeed.com' + soup.find('a', {'aria-label': 'Next'}).get('href')
    except AttributeError:
        break

    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    cards = soup.find_all('a', class_="tapItem")

    for card in cards:
        record = get_record(card)
        records.append(record)

# %% [markdown]
# ### Putting it all together

# %%
import csv
from datetime import datetime
import requests
from bs4 import BeautifulSoup


def get_url(position, location):
    """Generate url from position and location"""
    template = 'https://www.indeed.com/jobs?q={}&l={}'
    position = position.replace(' ', '+')
    location = location.replace(' ', '+')
    url = template.format(position, location)
    return url


def get_record(card):
    """Extract job data from a single record"""
    
    job_title = card.find('h2').get_text()
    company = card.find('span', class_='companyName').get_text()
    job_location = card.find('div', class_='companyLocation').get_text()
    post_date = card.find('span', 'date').text
    today = datetime.today().strftime('%Y-%m-%d')
    summary = card.find('div', class_='job-snippet').get_text().strip()
    job_url = 'https://www.indeed.com' + card['href']
    job_description = jd_soup.find("div", id="jobDescriptionText").text

    # this does not exists for all jobs, so handle the exceptions
    salary_tag = card.find('span', 'salaryText')
    if salary_tag:
        salary = salary_tag.text.strip()
    else:
        salary = ''  
        
    record = (job_title, company, job_location, post_date, today, summary, salary, job_url)
    return record


def main(position, location):
    """Run the main program routine"""
    records = []
    url = get_url(position, location)
    
    # extract the job data
    while True:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        cards = soup.find_all('a', class_="tapItem")
        for card in cards:
            record = get_record(card)
            records.append(record)
        try:
            url = 'https://www.indeed.com' + soup.find('a', {'aria-label': 'Next'}).get('href')
        except AttributeError:
            break
        
    # save the job data
    with open('results_2.csv', 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(['JobTitle', 'Company', 'Location', 'PostDate', 'ExtractDate', 'Summary', 'Salary', 'JobUrl','JobDescription'])
        writer.writerows(records)

# %%
# run the main program
main('senior accountant', 'charlotte nc')
